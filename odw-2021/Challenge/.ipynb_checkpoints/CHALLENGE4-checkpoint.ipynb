# %%
from gwpy.timeseries import TimeSeries
data1= TimeSeries.read('challenge3.gwf', 'H1:CHALLENGE3')
data2=TimeSeries.read('challenge3.gwf', 'L1:CHALLENGE3')

# %%
from pycbc.frame import read_frame

ts_H1 = read_frame("challenge3.gwf", "H1:CHALLENGE3")

print("Duration_H1: {}s delta_t_H1: {}s sampling rate_H1: {}Hz Start_H1: {} End_H1: {}".format(ts_H1.duration, ts_H1.delta_t, 1/ts_H1.delta_t,
                                              int(ts_H1.start_time),
                                              int(ts_H1.end_time)))

ts_L1 = read_frame("challenge3.gwf", "L1:CHALLENGE3")

print("Duration_L1: {}s delta_t_L1: {}s sampling rate_L1: {}Hz Start_L1: {} End_L1: {}".format(ts_L1.duration, ts_L1.delta_t, 1/ts_L1.delta_t,
                                              int(ts_L1.start_time),
                                              int(ts_L1.end_time)))
# Out:
# Duration_H1: 4096.0s delta_t_H1: 0.000244140625s sampling rate_H1: 4096.0Hz Start_H1: 0 End_H1: 4096
# Duration_L1: 4096.0s delta_t_L1: 0.000244140625s sampling rate_L1: 4096.0Hz Start_L1: 0 End_L1: 4096

# %%
from pycbc.filter import resample_to_delta_t, highpass
from pycbc.catalog import Merger
from pycbc.psd import interpolate, inverse_spectrum_truncation

data_H1 = resample_to_delta_t(ts_H1, 1.0/2048).crop(2, 2)

p_H1 = data_H1.psd(2)
p_H1 = interpolate(p_H1, data_H1.delta_f)
p_H1 = inverse_spectrum_truncation(p_H1, 2 * data_H1.sample_rate, low_frequency_cutoff=15.0)
psd_H1 = p_H1

data_L1 = resample_to_delta_t(ts_L1, 1.0/2048).crop(2, 2)

p_L1 = data_L1.psd(2)
p_L1 = interpolate(p_L1, data_L1.delta_f)
p_L1 = inverse_spectrum_truncation(p_L1, 2 * data_L1.sample_rate, low_frequency_cutoff=15.0)
psd_L1 = p_L1

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[34m'
   GREEN = '\033[32m'
   LIGHTGREEN = '\033[38;5;40m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
   ITALICS = '\033[3m'
   ITAB = '\033[3;1m'
   BLUEB = '\033[34;1m'
   GREENB = '\033[32;1m'
   CYANB = '\033[36;1m' 
   BLIGHTGREEN = '\033[38;5;1;40m' 
   REDB = '\033[91;1m'

# %%
import numpy as np
from gwpy.timeseries import TimeSeries
from pycbc.frame import read_frame
from pycbc.filter import resample_to_delta_t, highpass
from pycbc.psd import interpolate, inverse_spectrum_truncation
from colorama import Fore, Back, Style
from pycbc.waveform import get_fd_waveform
from pycbc.filter import matched_filter
from pycbc.vetoes import power_chisq
from pycbc.events.ranking import newsnr
import matplotlib.pyplot as plt
import pandas as pd

# %%
masses = []
dth = 8  # BBH merger signal threshold
BBH_dg = 750
# Assuming that for any apparent signal detected there will be no other merger
# peak within .36secs on either side of the said tentative detection as\
# it is implausible

nbins = 26  # for the reduced chisq filtering of removing glitches
dof = nbins * 2 - 2  # for the reduced chisq filtering of removing glitches

for x in range(10, 51):
    print(Style.RESET_ALL)
    print(color.BOLD + "Individual masses of the BBHs -- ", x, "solar masses" + color.END)
    print(Style.RESET_ALL)

    hp1, _ = get_fd_waveform(
        approximant="IMRPhenomD",
        mass1=x,
        mass2=x,
        delta_f=data_H1.delta_f,
        f_lower=20.0)

    hp1.resize(len(psd_H1))

    snr1 = matched_filter(hp1, data_H1, psd=psd_H1, low_frequency_cutoff=20)

    snr1 = snr1.crop(5, 4)
    peak1 = abs(snr1).numpy().argmax()
    snrp1 = snr1[peak1]
    time1 = snr1.sample_times[peak1]

    hp2, _ = get_fd_waveform(
        approximant="IMRPhenomD",
        mass1=x,
        mass2=x,
        delta_f=data_L1.delta_f,
        f_lower=20.0)

    hp2.resize(len(psd_L1))

    snr2 = matched_filter(hp2, data_L1, psd=psd_L1, low_frequency_cutoff=20)

    snr2 = snr2.crop(5, 4)
    peak2 = abs(snr2).numpy().argmax()
    snrp2 = snr2[peak2]
    time2 = snr2.sample_times[peak2]

    plt.figure(figsize=[13.27, 5.17])
    plt.plot(snr1.sample_times, abs(snr1), "-b")
    plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
    plt.title("All Possible Signal Candidates in H1")
    plt.ylabel("Signal-to-noise")
    plt.xlabel("Time (s)")
    plt.show()

    df_1 = pd.DataFrame({"snr1_x": snr1.sample_times, "snr1_y": abs(snr1).numpy()})

    maxv_snr1 = df_1["snr1_y"].max()
    max_i1 = df_1["snr1_y"].idxmax()
    snr1_xmax = df_1["snr1_x"][max_i1]
    snr1_ymax = df_1["snr1_y"][max_i1]

    if maxv_snr1 >= dth:
        print(
            color.BLUEB + "Listing all the possible signal candidates(for BH mass=", x, "solar mass) at Hanford in order of decreasing SNR" + color.END)
        print(Style.RESET_ALL)
        x_mx1l = []
        y_mx1l = []
        while maxv_snr1 >= dth:
            print(color.CYAN + "We found a possible signal candidate in H1 at", str(snr1_xmax), "s with SNR", str(snr1_ymax) + color.END)

            x_mx1l.append(snr1_xmax)
            y_mx1l.append(snr1_ymax)
            df_1 = df_1.drop(labels=range(max_i1 - BBH_dg, max_i1 + BBH_dg), axis=0)
            maxv_snr1 = df_1["snr1_y"].max()
            max_i1 = df_1["snr1_y"].idxmax()
            snr1_xmax = df_1["snr1_x"][max_i1]
            snr1_ymax = df_1["snr1_y"][max_i1]

        print(Style.RESET_ALL)

        x_mx1ar = np.asarray(x_mx1l)
        y_mx1ar = np.asarray(y_mx1l)
        dfo_1 = (pd.DataFrame({"x1": x_mx1ar, "y1": y_mx1ar}).sort_values("x1").reset_index())

    else:
        print(color.BLUEB + "There were no signal candidates at Hanford" + color.END)
        print(Style.RESET_ALL)

    plt.figure(figsize=[13.27, 5.17])
    plt.plot(snr2.sample_times, abs(snr2), "-g")
    plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
    plt.title("All Possible Signal Candidates in L1")
    plt.ylabel("Signal-to-noise")
    plt.xlabel("Time (s)")
    plt.show()

    df_2 = pd.DataFrame({"snr2_x": snr2.sample_times, "snr2_y": abs(snr2).numpy()})

    maxv_snr2 = df_2["snr2_y"].max()
    max_i2 = df_2["snr2_y"].idxmax()
    snr2_xmax = df_2["snr2_x"][max_i2]
    snr2_ymax = df_2["snr2_y"][max_i2]

    if maxv_snr2 >= dth:
        print(color.GREENB + "Listing all the possible signal candidates(for BH mass=", x, "solar mass) at Livingston in order of decreasing SNR" + color.END)
        print(Style.RESET_ALL)
        x_mx2l = []
        y_mx2l = []
        while maxv_snr2 >= dth:
            print(color.LIGHTGREEN + "We found a possible signal candidate in L1 at", str(snr2_xmax), "s with SNR", str(snr2_ymax) + color.END)

            x_mx2l.append(snr2_xmax)
            y_mx2l.append(snr2_ymax)
            df_2 = df_2.drop(labels=range(max_i2 - BBH_dg, max_i2 + BBH_dg), axis=0)
            maxv_snr2 = df_2["snr2_y"].max()
            max_i2 = df_2["snr2_y"].idxmax()
            snr2_xmax = df_2["snr2_x"][max_i2]
            snr2_ymax = df_2["snr2_y"][max_i2]

        print(Style.RESET_ALL)

        x_mx2ar = np.asarray(x_mx2l)
        y_mx2ar = np.asarray(y_mx2l)
        dfo_2 = (pd.DataFrame({"x2": x_mx2ar, "y2": y_mx2ar}).sort_values("x2").reset_index())
    else:
        print(color.GREENB + "There were no signal candidates at Livingston" + color.END)
        print(Style.RESET_ALL)

    chisq_H1 = power_chisq(hp1, data_H1, nbins, psd_H1, low_frequency_cutoff=20.0)
    chisq_H1 = chisq_H1.crop(5, 4)
    chisq_H1 /= dof
    nsnr1 = newsnr(abs(snr1), chisq_H1)
    peak_H1 = nsnr1.argmax()
    snrp_H1 = nsnr1[peak_H1]
    time_H1 = snr1.sample_times[peak_H1]

    chisq_L1 = power_chisq(hp2, data_L1, nbins, psd_L1, low_frequency_cutoff=20.0)
    chisq_L1 = chisq_L1.crop(5, 4)
    chisq_L1 /= dof
    nsnr2 = newsnr(abs(snr2), chisq_L1)
    peak_L1 = nsnr2.argmax()
    snrp_L1 = nsnr2[peak_L1]
    time_L1 = snr2.sample_times[peak_L1]

    if snrp_H1 > dth:
        # print("For the Hanford data we found a confirmed signal at {}s with SNR {} after ruling out the other candidates as glitches".format(time_H1, abs(snrp_H1)))
        # print(Style.RESET_ALL)
        plt.figure(figsize=[13.27, 5.17])
        plt.plot(snr1.sample_times, nsnr1, "-b")
        plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
        plt.title("Remaining Signal Candidate in H1 after reweighing data")
        plt.xlabel("Time (s)")
        plt.ylabel("Re-weighted Signal-to-noise")
        plt.show()

        ndf_1 = pd.DataFrame({"x1": snr1.sample_times, "y1": nsnr1})
        max_value1 = ndf_1["y1"].max()
        max_index1 = ndf_1["y1"].idxmax()
        x_max1 = ndf_1["x1"][max_index1]
        y_max1 = ndf_1["y1"][max_index1]

        if max_value1 >= dth:
            # print(color.BOLD + "Listing all the remaining signal candidate(s) at Hanford" + color.END)
            # print(Style.RESET_ALL)
            x_max1l = []
            y_max1l = []
            while max_value1 >= dth:
                # print("We found a confirmed signal candidate in H1 at", x_max1,"s with SNR", y_max1)
                x_max1l.append(x_max1)
                y_max1l.append(y_max1)
                ndf_1 = ndf_1.drop(labels=range(max_index1 - BBH_dg, max_index1 + BBH_dg), axis=0)
                max_value1 = ndf_1["y1"].max()
                max_index1 = ndf_1["y1"].idxmax()
                x_max1 = ndf_1["x1"][max_index1]
                y_max1 = ndf_1["y1"][max_index1]

            x_max1ar = np.asarray(x_max1l)
            y_max1ar = np.asarray(y_max1l)
            dfn_1 = (pd.DataFrame({"X1": x_max1ar, "Y1": y_max1ar}).sort_values("X1").reset_index())
            cond1 = dfo_1["x1"].isin(dfn_1["X1"])  # condition for extracting glitches in H1
            dfo_gl1 = dfo_1.drop(dfo_1[cond1].index, inplace=False)  # glitch dataframe for H1
            dfo_gl1 = dfo_gl1.reset_index()

    else:
        print(color.BLUEB + "There were no signal candidates at Hanford for template using m1=m2=", x, "solar masses" + color.END)
        print(Style.RESET_ALL)
        dfo_gl1 = dfo_1
        dfn_1 = []

    if snrp_L1 > dth:
        # print("For the Livingston data we found a confirmed signal at {}s with SNR {} after ruling out the other candidates as glitches".format(time_L1, abs(snrp_L1)))
        # print(Style.RESET_ALL)
        plt.figure(figsize=[13.27, 5.17])
        plt.plot(snr2.sample_times, nsnr2, "-g")
        plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
        plt.title("Remaining Signal Candidate in L1 after reweighing data")
        plt.xlabel("Time (s)")
        plt.ylabel("Re-weighted Signal-to-noise")
        plt.show()

        ndf_2 = pd.DataFrame({"x2": snr2.sample_times, "y2": nsnr2})
        max_value2 = ndf_2["y2"].max()
        max_index2 = ndf_2["y2"].idxmax()
        x_max2 = ndf_2["x2"][max_index2]
        y_max2 = ndf_2["y2"][max_index2]

        if max_value2 >= dth:
            # print(color.BOLD + "Listing all the remaining signal candidate(s) at Livingston" + color.END)
            # print(Style.RESET_ALL)
            x_max2l = []
            y_max2l = []
            while max_value2 >= dth:
                # print("We found a confirmed signal candidate in L1 at", x_max2,"s with SNR", y_max2)

                x_max2l.append(x_max2)
                y_max2l.append(y_max2)
                ndf_2 = ndf_2.drop(labels=range(max_index2 - BBH_dg, max_index2 + BBH_dg), axis=0)
                max_value2 = ndf_2["y2"].max()
                max_index2 = ndf_2["y2"].idxmax()
                x_max2 = ndf_2["x2"][max_index2]
                y_max2 = ndf_2["y2"][max_index2]

            x_max2ar = np.asarray(x_max2l)
            y_max2ar = np.asarray(y_max2l)
            dfn_2 = (pd.DataFrame({"X2": x_max2ar, "Y2": y_max2ar}).sort_values("X2").reset_index())
            cond2 = dfo_2["x2"].isin(dfn_2["X2"])  # condition for extracting glitches in L1
            dfo_gl2 = dfo_2.drop(dfo_2[cond2].index, inplace=False)  # glitch dataframe for L1
            dfo_gl2 = dfo_gl2.reset_index()

    else:
        print(color.GREENB + "There were no signal candidates at Livingston for template using m1=m2=", x, "solar masses" + color.END)
        print(Style.RESET_ALL)
        dfo_gl2 = dfo_2
        dfn_2 = []

    ############################################################
    ############################################################
    if (snrp_H1 > dth) or (snrp_L1 > dth) or ((snrp_H1 > dth) and (snrp_L1 > dth)):

        if len(dfn_1) > 0 and len(dfn_2) == 0:
            print(color.BLUEB + "There are no surviving signal candidates in L1 whereas for H1 we have", len(dfn_1), "candidates:" + color.END)
            print(Style.RESET_ALL)
            for i in range(0, dfn_1.index[-1] + 1):
                print(color.CYAN + "The signal candidate in H1 at", str(dfn_1["X1"][i]), "has a SNR of", str(dfn_1["Y1"][i]) + color.END)
            print(Style.RESET_ALL)
            print(color.GREENB + "The following signal candidates in L1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)
            for b in range(0, dfo_2.index[-1] + 1):
                print(color.LIGHTGREEN + "The initial signal candidate at L1 reported at", str(dfo_2["x2"][b]), "was a glitch" + color.END)

        elif len(dfn_2) > 0 and len(dfn_1) == 0:
            print(color.GREENB + "There are no surviving signal candidates in H1 whereas for L1 we have", len(dfn_2), "candidates:" + color.END)
            print(Style.RESET_ALL)
            for j in range(0, dfn_2.index[-1] + 1):
                print(color.LIGHTGREEN + "The signal candidate in L1 at", str(dfn_2["X2"][j]), "has a SNR of", str(dfn_2["Y2"][j]) + color.END)
            print(Style.RESET_ALL)
            print(color.BLUEB + "The following signal candidates in H1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)
            for a in range(0, dfo_1.index[-1] + 1):
                print(color.CYAN + "The initial signal candidate at H1 reported at", str(dfo_1["x1"][a]), "was a glitch" + color.END)

        elif len(dfn_2) > 0 and len(dfn_1) > 0:
            print(color.BLUEB + "The following signal candidates in H1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)

            if len(dfo_gl1) != 0:
                for g1 in range(0, dfo_gl1.index[-1] + 1):
                    print(color.CYAN + "The initial signal candidate at H1 reported at", str(dfo_gl1["x1"][g1]), "was a glitch" + color.END)
            if len(dfo_gl1) < len(dfo_1):
                print(Style.RESET_ALL)
                print(color.BLUEB + "The surviving signal candidates in H1 are:" + color.END)
                print(Style.RESET_ALL)
                for i in range(0, dfn_1.index[-1] + 1):
                    print(color.CYAN + "There is a signal candidate in H1 at", str(dfn_1["X1"][i]), "with SNR", str(dfn_1["Y1"][i]) + color.END)

            print(Style.RESET_ALL)
            print(color.GREENB + "The following signal candidates in L1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)

            if len(dfo_gl2) != 0:
                for g2 in range(0, dfo_gl2.index[-1] + 1):
                    print(color.LIGHTGREEN + "The initial signal candidate at L1 reported at", str(dfo_gl2["x2"][g2]), "was a glitch" + color.END)
            if len(dfo_gl2) < len(dfo_2):
                print(Style.RESET_ALL)
                print(color.GREENB + "The surviving signal candidates in L1 are:" + color.END)
                print(Style.RESET_ALL)
                for j in range(0, dfn_2.index[-1] + 1):
                    print(color.LIGHTGREEN + "There is a signal candidate in L1 at", str(dfn_2["X2"][j]), "with SNR", str(dfn_2["Y2"][j]) + color.END)

            print(Style.RESET_ALL)
            print(color.BOLD + "Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:" + color.END)
            # print(Style.RESET_ALL)

            for i in range(0, dfn_1.index[-1] + 1):
                for j in range(0, dfn_2.index[-1] + 1):

                    if abs(dfn_2["X2"][j] - dfn_1["X1"][i]) > 3:
                        print(Style.RESET_ALL)
                        print(color.BOLD + "The signals at", str(dfn_1["X1"][i]), "for H1 and at", str(dfn_2["X2"][j]), "for L1 are too far apart with a lag of", str(abs(dfn_2["X2"][j] - dfn_1["X1"][i])), "s" + color.END)

                    elif dfn_1["X1"][i] == dfn_2["X2"][j]:
                        print(Style.RESET_ALL)
                        print(color.BOLD + "As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at", str(dfn_1["X1"][i]), "\nwith the H1 SNR", str(dfn_1["Y1"][i]), "and the L1 SNR", str(dfn_2["Y2"][j]) + color.END)
                        print(Style.RESET_ALL)

                    elif abs(dfn_2["X2"][j] - dfn_1["X1"][i]) < 0.008961194:
                        # print(Style.RESET_ALL)
                        print(color.BOLD + "The time lag", str(abs(dfn_2["X2"][j] - dfn_1["X1"][i])), "s between the signals at H1 & L1 is too short compared to GW travel time and hence \nan artefact of other noise sources or some artificial source" + color.END)
                        print(Style.RESET_ALL)

                    elif dfn_2["X2"][j] - 3 <= dfn_1["X1"][i] <= dfn_2["X2"][j] + 3:
                        if abs(dfn_2["X2"][j] - dfn_1["X1"][i]) > 0.011328301:
                            print(Style.RESET_ALL)
                            print(color.BOLD + "While the time lag", str(abs(dfn_2["X2"][j] - dfn_1["X1"][i])), "s is short it is too large compared to GW travel time and hence an artefact of other noise sources" + color.END)
                            print(Style.RESET_ALL)

                    elif (dfn_2["X2"][j] - 0.008961194 <= dfn_1["X1"][i] <= dfn_2["X2"][j] + 0.008961194):
                        print(Style.RESET_ALL)
                        print(color.CYAN + "We found a BBH merger candidate \nin H1 at", str(dfn_1["X1"][i]), "with SNR", str(dfn_1["Y1"][i]), "and \nin L1 at", str(dfn_2["X2"][j]), "with SNR", str(dfn_2["Y2"][j]) + color.END)
                        print(Style.RESET_ALL)

                    elif (abs(dfn_2["X2"][j] - dfn_1["X1"][i]) >= 0.008961194) and (abs(dfn_2["X2"][j] - dfn_1["X1"][i]) < 0.011328301):
                        print(Style.RESET_ALL)
                        print(color.BLUEB + "We found a signal candidate \nin H1 at", str(dfn_1["X1"][i]), "with SNR", str(dfn_1["Y1"][i]), "and \nin L1 at", str(dfn_2["X2"][j]), "with SNR", str(dfn_2["Y2"][j]) + color.END)
                        print(color.BOLD + "The above signal is an extremely likely candidate for an authentic BBH merger given the choice of template" + color.END)
                        print(color.BOLD + "The time lag", str(abs(dfn_2["X2"][j] - dfn_1["X1"][i])), "s between the signals at H1 & L1 is comparable to GW travel time" + color.END)
                        # print(Style.RESET_ALL)
                    else:
                        print(color.BLUEB + "yipee" + color.END)

    else:
        # print("Glitches and remaining signals")
        print(Style.RESET_ALL)
        # if len(dfn_1) == 0 and len(dfn_2) == 0:
        print(color.REDB + "There are no remaining signal candidates in both H1 and L1" + color.END)
        print(Style.RESET_ALL)
        for a in range(0, dfo_1.index[-1] + 1):
            print(color.CYAN + "The initial signal candidate at H1 reported at", str(dfo_1["x1"][a]), "was a glitch" + color.END)
        print(Style.RESET_ALL)
        for b in range(0, dfo_2.index[-1] + 1):
            print(color.LIGHTGREEN + "The initial signal candidate at L1 reported at", str(dfo_2["x2"][b]), "was a glitch" + color.END)

    ############################################################
    ############################################################
    
    masses.append(x)
# Out:
# Individual masses of the BBHs --  10 solar masses
# Listing all the possible signal candidates(for BH mass= 10 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 2483.96875 s with SNR 28.636095483197217
# We found a possible signal candidate in H1 at 1204.71435546875 s with SNR 11.702049219691768
# We found a possible signal candidate in H1 at 1638.17919921875 s with SNR 9.390212390406695
# Listing all the possible signal candidates(for BH mass= 10 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 2483.96875 s with SNR 33.341233755976305
# We found a possible signal candidate in L1 at 1204.8291015625 s with SNR 10.042547054458854
# We found a possible signal candidate in L1 at 1638.2607421875 s with SNR 8.684190520088428
# The following signal candidates in H1 were ruled out as glitches:
#
# The initial signal candidate at H1 reported at 1204.71435546875 was a glitch
# The initial signal candidate at H1 reported at 1638.17919921875 was a glitch
#
# The surviving signal candidates in H1 are:
#
# There is a signal candidate in H1 at 2483.96875 with SNR 26.83894692403943
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 1204.8291015625 was a glitch
# The initial signal candidate at L1 reported at 1638.2607421875 was a glitch
#
# The surviving signal candidates in L1 are:
#
# There is a signal candidate in L1 at 2483.96875 with SNR 31.238798653463572
#
# Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:
#
# As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at 2483.96875
# with the H1 SNR 26.83894692403943 and the L1 SNR 31.238798653463572
#
#
# Individual masses of the BBHs --  11 solar masses
# Listing all the possible signal candidates(for BH mass= 11 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.71435546875 s with SNR 12.010612275705922
# We found a possible signal candidate in H1 at 2483.966796875 s with SNR 11.231273519309354
# We found a possible signal candidate in H1 at 1638.17529296875 s with SNR 9.899291809240776
# Listing all the possible signal candidates(for BH mass= 11 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 2483.95849609375 s with SNR 11.14999648756963
# We found a possible signal candidate in L1 at 1204.7568359375 s with SNR 10.89348320653851
# We found a possible signal candidate in L1 at 1638.2138671875 s with SNR 9.920050826735691
#
# There were no signal candidates at Hanford for template using m1=m2= 11 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 11 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.71435546875 was a glitch
# The initial signal candidate at H1 reported at 1638.17529296875 was a glitch
# The initial signal candidate at H1 reported at 2483.966796875 was a glitch
#
# The initial signal candidate at L1 reported at 1204.7568359375 was a glitch
# The initial signal candidate at L1 reported at 1638.2138671875 was a glitch
# The initial signal candidate at L1 reported at 2483.95849609375 was a glitch
#
# Individual masses of the BBHs --  12 solar masses
# Listing all the possible signal candidates(for BH mass= 12 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.712890625 s with SNR 13.61334652970294
# We found a possible signal candidate in H1 at 1638.16015625 s with SNR 12.0022512758351
# We found a possible signal candidate in H1 at 2483.96240234375 s with SNR 9.525762768335422
# Listing all the possible signal candidates(for BH mass= 12 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.71875 s with SNR 12.425712403541418
# We found a possible signal candidate in L1 at 1638.19775390625 s with SNR 11.166635869567134
# We found a possible signal candidate in L1 at 2483.94482421875 s with SNR 8.820510679103657
#
# There were no signal candidates at Hanford for template using m1=m2= 12 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 12 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.712890625 was a glitch
# The initial signal candidate at H1 reported at 1638.16015625 was a glitch
# The initial signal candidate at H1 reported at 2483.96240234375 was a glitch
#
# The initial signal candidate at L1 reported at 1204.71875 was a glitch
# The initial signal candidate at L1 reported at 1638.19775390625 was a glitch
# The initial signal candidate at L1 reported at 2483.94482421875 was a glitch
#
# Individual masses of the BBHs --  13 solar masses
# Listing all the possible signal candidates(for BH mass= 13 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.71337890625 s with SNR 16.065475670098646
# We found a possible signal candidate in H1 at 1638.16259765625 s with SNR 14.089157913110924
# We found a possible signal candidate in H1 at 2483.9619140625 s with SNR 8.396240820990677
# Listing all the possible signal candidates(for BH mass= 13 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.71337890625 s with SNR 13.575676122417033
# We found a possible signal candidate in L1 at 1638.171875 s with SNR 12.694326457413277
# We found a possible signal candidate in L1 at 196.1171875 s with SNR 8.173571658582452
#
# There were no signal candidates at Hanford for template using m1=m2= 13 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 13 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.71337890625 was a glitch
# The initial signal candidate at H1 reported at 1638.16259765625 was a glitch
# The initial signal candidate at H1 reported at 2483.9619140625 was a glitch
#
# The initial signal candidate at L1 reported at 196.1171875 was a glitch
# The initial signal candidate at L1 reported at 1204.71337890625 was a glitch
# The initial signal candidate at L1 reported at 1638.171875 was a glitch
#
# Individual masses of the BBHs --  14 solar masses
# Listing all the possible signal candidates(for BH mass= 14 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1638.15966796875 s with SNR 16.53283963627555
# We found a possible signal candidate in H1 at 1204.712890625 s with SNR 15.374517466623125
# We found a possible signal candidate in H1 at 2483.95751953125 s with SNR 8.106724147285819
# Listing all the possible signal candidates(for BH mass= 14 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1638.16845703125 s with SNR 16.33009045443685
# We found a possible signal candidate in L1 at 1204.71337890625 s with SNR 14.648026214277921
#
# There were no signal candidates at Hanford for template using m1=m2= 14 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 14 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.712890625 was a glitch
# The initial signal candidate at H1 reported at 1638.15966796875 was a glitch
# The initial signal candidate at H1 reported at 2483.95751953125 was a glitch
#
# The initial signal candidate at L1 reported at 1204.71337890625 was a glitch
# The initial signal candidate at L1 reported at 1638.16845703125 was a glitch
#
# Individual masses of the BBHs --  15 solar masses
# Listing all the possible signal candidates(for BH mass= 15 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1638.1591796875 s with SNR 18.24510667937225
# We found a possible signal candidate in H1 at 1204.71240234375 s with SNR 18.094226337899073
# Listing all the possible signal candidates(for BH mass= 15 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1638.1591796875 s with SNR 17.873869530652915
# We found a possible signal candidate in L1 at 1204.71240234375 s with SNR 16.26292350798875
# We found a possible signal candidate in L1 at 196.0849609375 s with SNR 8.379576138774858
#
# There were no signal candidates at Hanford for template using m1=m2= 15 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 15 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.71240234375 was a glitch
# The initial signal candidate at H1 reported at 1638.1591796875 was a glitch
#
# The initial signal candidate at L1 reported at 196.0849609375 was a glitch
# The initial signal candidate at L1 reported at 1204.71240234375 was a glitch
# The initial signal candidate at L1 reported at 1638.1591796875 was a glitch
#
# Individual masses of the BBHs --  16 solar masses
# Listing all the possible signal candidates(for BH mass= 16 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1638.1591796875 s with SNR 25.191636821027544
# We found a possible signal candidate in H1 at 1204.71240234375 s with SNR 19.08261541628588
# We found a possible signal candidate in H1 at 2483.96044921875 s with SNR 8.084097090068829
# Listing all the possible signal candidates(for BH mass= 16 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1638.1591796875 s with SNR 21.936639174654065
# We found a possible signal candidate in L1 at 1204.712890625 s with SNR 17.968349736688534
# We found a possible signal candidate in L1 at 196.09765625 s with SNR 8.810552758366331
#
# There were no signal candidates at Hanford for template using m1=m2= 16 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 16 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.71240234375 was a glitch
# The initial signal candidate at H1 reported at 1638.1591796875 was a glitch
# The initial signal candidate at H1 reported at 2483.96044921875 was a glitch
#
# The initial signal candidate at L1 reported at 196.09765625 was a glitch
# The initial signal candidate at L1 reported at 1204.712890625 was a glitch
# The initial signal candidate at L1 reported at 1638.1591796875 was a glitch
#
# Individual masses of the BBHs --  17 solar masses
# Listing all the possible signal candidates(for BH mass= 17 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1638.158203125 s with SNR 38.35809977605657
# We found a possible signal candidate in H1 at 1204.7119140625 s with SNR 22.47476570712831
# We found a possible signal candidate in H1 at 3319.25927734375 s with SNR 8.130340680067421
# Listing all the possible signal candidates(for BH mass= 17 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1638.158203125 s with SNR 42.892923673748264
# We found a possible signal candidate in L1 at 1204.71240234375 s with SNR 20.569906021579467
# We found a possible signal candidate in L1 at 196.087890625 s with SNR 9.22395439998914
# The following signal candidates in H1 were ruled out as glitches:
#
# The initial signal candidate at H1 reported at 1204.7119140625 was a glitch
# The initial signal candidate at H1 reported at 3319.25927734375 was a glitch
#
# The surviving signal candidates in H1 are:
#
# There is a signal candidate in H1 at 1638.158203125 with SNR 33.60702276446743
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.087890625 was a glitch
# The initial signal candidate at L1 reported at 1204.71240234375 was a glitch
#
# The surviving signal candidates in L1 are:
#
# There is a signal candidate in L1 at 1638.158203125 with SNR 39.113634791318034
#
# Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:
#
# As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at 1638.158203125
# with the H1 SNR 33.60702276446743 and the L1 SNR 39.113634791318034
#
#
# Individual masses of the BBHs --  18 solar masses
# Listing all the possible signal candidates(for BH mass= 18 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1638.1572265625 s with SNR 26.501269399933967
# We found a possible signal candidate in H1 at 1204.71142578125 s with SNR 22.16834399065227
# Listing all the possible signal candidates(for BH mass= 18 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1638.1572265625 s with SNR 27.530801282995228
# We found a possible signal candidate in L1 at 1204.7119140625 s with SNR 24.003913285087993
# We found a possible signal candidate in L1 at 196.08642578125 s with SNR 9.382715825463052
#
# There were no signal candidates at Hanford for template using m1=m2= 18 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 18 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.71142578125 was a glitch
# The initial signal candidate at H1 reported at 1638.1572265625 was a glitch
#
# The initial signal candidate at L1 reported at 196.08642578125 was a glitch
# The initial signal candidate at L1 reported at 1204.7119140625 was a glitch
# The initial signal candidate at L1 reported at 1638.1572265625 was a glitch
#
# Individual masses of the BBHs --  19 solar masses
# Listing all the possible signal candidates(for BH mass= 19 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.7119140625 s with SNR 25.071228280250637
# We found a possible signal candidate in H1 at 1638.15673828125 s with SNR 21.950538125189173
# Listing all the possible signal candidates(for BH mass= 19 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.7119140625 s with SNR 26.71947245195162
# We found a possible signal candidate in L1 at 1638.15673828125 s with SNR 20.324085675085552
# We found a possible signal candidate in L1 at 196.0927734375 s with SNR 9.568913828988613
#
# There were no signal candidates at Hanford for template using m1=m2= 19 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 19 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.7119140625 was a glitch
# The initial signal candidate at H1 reported at 1638.15673828125 was a glitch
#
# The initial signal candidate at L1 reported at 196.0927734375 was a glitch
# The initial signal candidate at L1 reported at 1204.7119140625 was a glitch
# The initial signal candidate at L1 reported at 1638.15673828125 was a glitch
#
# Individual masses of the BBHs --  20 solar masses
# Listing all the possible signal candidates(for BH mass= 20 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.71142578125 s with SNR 31.011892345275083
# We found a possible signal candidate in H1 at 1638.15673828125 s with SNR 20.768806015041378
# Listing all the possible signal candidates(for BH mass= 20 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.71142578125 s with SNR 32.58021621937447
# We found a possible signal candidate in L1 at 1638.15673828125 s with SNR 18.761407881741583
# We found a possible signal candidate in L1 at 196.09619140625 s with SNR 10.148424089433908
#
# There were no signal candidates at Hanford for template using m1=m2= 20 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 20 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 1204.71142578125 was a glitch
# The initial signal candidate at H1 reported at 1638.15673828125 was a glitch
#
# The initial signal candidate at L1 reported at 196.09619140625 was a glitch
# The initial signal candidate at L1 reported at 1204.71142578125 was a glitch
# The initial signal candidate at L1 reported at 1638.15673828125 was a glitch
#
# Individual masses of the BBHs --  21 solar masses
# Listing all the possible signal candidates(for BH mass= 21 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.7109375 s with SNR 36.61026525848635
# We found a possible signal candidate in H1 at 1638.15673828125 s with SNR 19.586110314474308
# Listing all the possible signal candidates(for BH mass= 21 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.71142578125 s with SNR 39.28947875738411
# We found a possible signal candidate in L1 at 1638.15625 s with SNR 18.929133479199063
# We found a possible signal candidate in L1 at 196.09228515625 s with SNR 10.801872034554778
# The following signal candidates in H1 were ruled out as glitches:
#
# The initial signal candidate at H1 reported at 1638.15673828125 was a glitch
#
# The surviving signal candidates in H1 are:
#
# There is a signal candidate in H1 at 1204.7109375 with SNR 11.128623993223117
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.09228515625 was a glitch
# The initial signal candidate at L1 reported at 1638.15625 was a glitch
#
# The surviving signal candidates in L1 are:
#
# There is a signal candidate in L1 at 1204.71142578125 with SNR 8.63235668375633
#
# Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:
# The time lag 0.00048828125 s between the signals at H1 & L1 is too short compared to GW travel time and hence
# an artefact of other noise sources or some artificial source
#
#
# Individual masses of the BBHs --  22 solar masses
# Listing all the possible signal candidates(for BH mass= 22 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.71044921875 s with SNR 44.58515807711841
# We found a possible signal candidate in H1 at 1638.15576171875 s with SNR 19.457874744260526
# We found a possible signal candidate in H1 at 3319.25732421875 s with SNR 8.40317545789313
# Listing all the possible signal candidates(for BH mass= 22 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.71044921875 s with SNR 53.15021786120631
# We found a possible signal candidate in L1 at 1638.1552734375 s with SNR 17.99822531220326
# We found a possible signal candidate in L1 at 196.091796875 s with SNR 10.891380648640345
# We found a possible signal candidate in L1 at 3319.2568359375 s with SNR 8.219733319345915
# The following signal candidates in H1 were ruled out as glitches:
#
# The initial signal candidate at H1 reported at 1638.15576171875 was a glitch
# The initial signal candidate at H1 reported at 3319.25732421875 was a glitch
#
# The surviving signal candidates in H1 are:
#
# There is a signal candidate in H1 at 1204.71044921875 with SNR 38.38671861918196
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.091796875 was a glitch
# The initial signal candidate at L1 reported at 1638.1552734375 was a glitch
# The initial signal candidate at L1 reported at 3319.2568359375 was a glitch
#
# The surviving signal candidates in L1 are:
#
# There is a signal candidate in L1 at 1204.71044921875 with SNR 50.73312219066988
#
# Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:
#
# As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at 1204.71044921875
# with the H1 SNR 38.38671861918196 and the L1 SNR 50.73312219066988
#
#
# Individual masses of the BBHs --  23 solar masses
# Listing all the possible signal candidates(for BH mass= 23 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70947265625 s with SNR 39.430598747813505
# We found a possible signal candidate in H1 at 1638.15576171875 s with SNR 18.73569011776919
# We found a possible signal candidate in H1 at 3319.2568359375 s with SNR 8.00440768111127
# Listing all the possible signal candidates(for BH mass= 23 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.70947265625 s with SNR 45.0983587728582
# We found a possible signal candidate in L1 at 1638.1494140625 s with SNR 15.979264906952482
# We found a possible signal candidate in L1 at 196.083984375 s with SNR 11.289913302779622
# The following signal candidates in H1 were ruled out as glitches:
#
# The initial signal candidate at H1 reported at 1638.15576171875 was a glitch
# The initial signal candidate at H1 reported at 3319.2568359375 was a glitch
#
# The surviving signal candidates in H1 are:
#
# There is a signal candidate in H1 at 1204.70947265625 with SNR 14.515012162748901
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.083984375 was a glitch
# The initial signal candidate at L1 reported at 1638.1494140625 was a glitch
#
# The surviving signal candidates in L1 are:
#
# There is a signal candidate in L1 at 1204.70947265625 with SNR 12.51080741566826
#
# Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:
#
# As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at 1204.70947265625
# with the H1 SNR 14.515012162748901 and the L1 SNR 12.51080741566826
#
#
# Individual masses of the BBHs --  24 solar masses
# Listing all the possible signal candidates(for BH mass= 24 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.708984375 s with SNR 34.869243444719174
# We found a possible signal candidate in H1 at 1638.15576171875 s with SNR 19.127830333439434
# We found a possible signal candidate in H1 at 987.6953125 s with SNR 8.056607745223411
# Listing all the possible signal candidates(for BH mass= 24 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.708984375 s with SNR 37.268655574335966
# We found a possible signal candidate in L1 at 1638.146484375 s with SNR 15.372437512299232
# We found a possible signal candidate in L1 at 196.0908203125 s with SNR 12.356382833597321
# There were no signal candidates at Livingston for template using m1=m2= 24 solar masses
#
# There are no surviving signal candidates in L1 whereas for H1 we have 1 candidates:
#
# The signal candidate in H1 at 1204.708984375 has a SNR of 9.985394499367287
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.0908203125 was a glitch
# The initial signal candidate at L1 reported at 1204.708984375 was a glitch
# The initial signal candidate at L1 reported at 1638.146484375 was a glitch
#
# Individual masses of the BBHs --  25 solar masses
# Listing all the possible signal candidates(for BH mass= 25 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70849609375 s with SNR 32.22982889941126
# We found a possible signal candidate in H1 at 1638.1552734375 s with SNR 19.611868517686286
# We found a possible signal candidate in H1 at 3319.25732421875 s with SNR 9.314453010422941
# We found a possible signal candidate in H1 at 987.6943359375 s with SNR 8.38397127350041
# We found a possible signal candidate in H1 at 2995.34521484375 s with SNR 8.020334505484737
# Listing all the possible signal candidates(for BH mass= 25 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.70849609375 s with SNR 35.29315012896096
# We found a possible signal candidate in L1 at 1638.14111328125 s with SNR 15.156220643155196
# We found a possible signal candidate in L1 at 196.08544921875 s with SNR 12.977767072062031
# There were no signal candidates at Livingston for template using m1=m2= 25 solar masses
#
# There are no surviving signal candidates in L1 whereas for H1 we have 1 candidates:
#
# The signal candidate in H1 at 1204.70849609375 has a SNR of 8.5646273333464
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.08544921875 was a glitch
# The initial signal candidate at L1 reported at 1204.70849609375 was a glitch
# The initial signal candidate at L1 reported at 1638.14111328125 was a glitch
#
# Individual masses of the BBHs --  26 solar masses
# Listing all the possible signal candidates(for BH mass= 26 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70849609375 s with SNR 30.450913716505273
# We found a possible signal candidate in H1 at 1638.15478515625 s with SNR 19.270106127952605
# We found a possible signal candidate in H1 at 3319.2568359375 s with SNR 9.881670096439162
# We found a possible signal candidate in H1 at 2995.3447265625 s with SNR 8.500813142247083
# We found a possible signal candidate in H1 at 987.68505859375 s with SNR 8.22247842269388
# Listing all the possible signal candidates(for BH mass= 26 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.7080078125 s with SNR 30.539727684772345
# We found a possible signal candidate in L1 at 1638.140625 s with SNR 14.83016127637032
# We found a possible signal candidate in L1 at 196.083984375 s with SNR 13.568688212732935
#
# There were no signal candidates at Hanford for template using m1=m2= 26 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 26 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 987.68505859375 was a glitch
# The initial signal candidate at H1 reported at 1204.70849609375 was a glitch
# The initial signal candidate at H1 reported at 1638.15478515625 was a glitch
# The initial signal candidate at H1 reported at 2995.3447265625 was a glitch
# The initial signal candidate at H1 reported at 3319.2568359375 was a glitch
#
# The initial signal candidate at L1 reported at 196.083984375 was a glitch
# The initial signal candidate at L1 reported at 1204.7080078125 was a glitch
# The initial signal candidate at L1 reported at 1638.140625 was a glitch
#
# Individual masses of the BBHs --  27 solar masses
# Listing all the possible signal candidates(for BH mass= 27 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.7080078125 s with SNR 28.761829371280392
# We found a possible signal candidate in H1 at 1638.15478515625 s with SNR 18.87243074231426
# We found a possible signal candidate in H1 at 3319.25634765625 s with SNR 9.580254363763784
# We found a possible signal candidate in H1 at 2995.3447265625 s with SNR 9.20887273458613
# We found a possible signal candidate in H1 at 987.69384765625 s with SNR 8.276422072005513
# Listing all the possible signal candidates(for BH mass= 27 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.7080078125 s with SNR 29.018185147525152
# We found a possible signal candidate in L1 at 196.0830078125 s with SNR 14.295989843069924
# We found a possible signal candidate in L1 at 1638.140625 s with SNR 14.24130804002104
# We found a possible signal candidate in L1 at 3319.2568359375 s with SNR 8.383585882400544
#
# There were no signal candidates at Hanford for template using m1=m2= 27 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 27 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 987.69384765625 was a glitch
# The initial signal candidate at H1 reported at 1204.7080078125 was a glitch
# The initial signal candidate at H1 reported at 1638.15478515625 was a glitch
# The initial signal candidate at H1 reported at 2995.3447265625 was a glitch
# The initial signal candidate at H1 reported at 3319.25634765625 was a glitch
#
# The initial signal candidate at L1 reported at 196.0830078125 was a glitch
# The initial signal candidate at L1 reported at 1204.7080078125 was a glitch
# The initial signal candidate at L1 reported at 1638.140625 was a glitch
# The initial signal candidate at L1 reported at 3319.2568359375 was a glitch
#
# Individual masses of the BBHs --  28 solar masses
# Listing all the possible signal candidates(for BH mass= 28 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.7080078125 s with SNR 27.974741294209824
# We found a possible signal candidate in H1 at 1638.154296875 s with SNR 18.925994650071463
# We found a possible signal candidate in H1 at 3319.25634765625 s with SNR 9.810157580816352
# We found a possible signal candidate in H1 at 2995.34423828125 s with SNR 9.54145818884813
# We found a possible signal candidate in H1 at 987.693359375 s with SNR 8.2647646645012
# Listing all the possible signal candidates(for BH mass= 28 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.7080078125 s with SNR 28.813074221159507
# We found a possible signal candidate in L1 at 196.08203125 s with SNR 13.835661313912325
# We found a possible signal candidate in L1 at 1638.14013671875 s with SNR 13.80245287600445
# We found a possible signal candidate in L1 at 3319.2568359375 s with SNR 10.219170655886698
#
# There were no signal candidates at Hanford for template using m1=m2= 28 solar masses
#
# There were no signal candidates at Livingston for template using m1=m2= 28 solar masses
#
# Glitches and remaining signals
#
# There are no remaining signal candidates in both H1 and L1
#
# The initial signal candidate at H1 reported at 987.693359375 was a glitch
# The initial signal candidate at H1 reported at 1204.7080078125 was a glitch
# The initial signal candidate at H1 reported at 1638.154296875 was a glitch
# The initial signal candidate at H1 reported at 2995.34423828125 was a glitch
# The initial signal candidate at H1 reported at 3319.25634765625 was a glitch
#
# The initial signal candidate at L1 reported at 196.08203125 was a glitch
# The initial signal candidate at L1 reported at 1204.7080078125 was a glitch
# The initial signal candidate at L1 reported at 1638.14013671875 was a glitch
# The initial signal candidate at L1 reported at 3319.2568359375 was a glitch
#
# Individual masses of the BBHs --  29 solar masses
# Listing all the possible signal candidates(for BH mass= 29 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70751953125 s with SNR 27.628766997477737
# We found a possible signal candidate in H1 at 1638.154296875 s with SNR 18.715214226466095
# We found a possible signal candidate in H1 at 3319.255859375 s with SNR 10.213916347075982
# We found a possible signal candidate in H1 at 2995.34375 s with SNR 9.917343677662094
# We found a possible signal candidate in H1 at 987.68408203125 s with SNR 8.333071849614377
# Listing all the possible signal candidates(for BH mass= 29 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.70751953125 s with SNR 27.879394257780092
# We found a possible signal candidate in L1 at 1638.14794921875 s with SNR 13.302530570594636
# We found a possible signal candidate in L1 at 196.08251953125 s with SNR 13.198249822455105
# We found a possible signal candidate in L1 at 3319.255859375 s with SNR 11.26670435576084
# There were no signal candidates at Livingston for template using m1=m2= 29 solar masses
#
# There are no surviving signal candidates in L1 whereas for H1 we have 1 candidates:
#
# The signal candidate in H1 at 2995.34375 has a SNR of 8.425225666008284
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.08251953125 was a glitch
# The initial signal candidate at L1 reported at 1204.70751953125 was a glitch
# The initial signal candidate at L1 reported at 1638.14794921875 was a glitch
# The initial signal candidate at L1 reported at 3319.255859375 was a glitch
#
# Individual masses of the BBHs --  30 solar masses
# Listing all the possible signal candidates(for BH mass= 30 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70751953125 s with SNR 27.442934934302848
# We found a possible signal candidate in H1 at 1638.15380859375 s with SNR 18.58860770971103
# We found a possible signal candidate in H1 at 2995.34375 s with SNR 10.91865440289467
# We found a possible signal candidate in H1 at 3319.255859375 s with SNR 10.606180434889234
# We found a possible signal candidate in H1 at 987.6923828125 s with SNR 8.310094136276861
# Listing all the possible signal candidates(for BH mass= 30 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.70751953125 s with SNR 27.433852940897715
# We found a possible signal candidate in L1 at 196.0830078125 s with SNR 14.09293763423611
# We found a possible signal candidate in L1 at 1638.14697265625 s with SNR 13.450131798326126
# We found a possible signal candidate in L1 at 3319.25537109375 s with SNR 11.61352681031279
# We found a possible signal candidate in L1 at 2995.3427734375 s with SNR 8.04149594518254
# There were no signal candidates at Livingston for template using m1=m2= 30 solar masses
#
# There are no surviving signal candidates in L1 whereas for H1 we have 1 candidates:
#
# The signal candidate in H1 at 2995.34375 has a SNR of 9.778238081523261
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.0830078125 was a glitch
# The initial signal candidate at L1 reported at 1204.70751953125 was a glitch
# The initial signal candidate at L1 reported at 1638.14697265625 was a glitch
# The initial signal candidate at L1 reported at 2995.3427734375 was a glitch
# The initial signal candidate at L1 reported at 3319.25537109375 was a glitch
#
# Individual masses of the BBHs --  31 solar masses
# Listing all the possible signal candidates(for BH mass= 31 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70751953125 s with SNR 27.216902536411336
# We found a possible signal candidate in H1 at 1638.15380859375 s with SNR 18.4585144217415
# We found a possible signal candidate in H1 at 2995.3427734375 s with SNR 11.318075593335392
# We found a possible signal candidate in H1 at 3319.255859375 s with SNR 11.2277687266115
# We found a possible signal candidate in H1 at 987.69189453125 s with SNR 8.73752794767838
# Listing all the possible signal candidates(for BH mass= 31 solar mass) at Livingston in order of decreasing SNR
#
# We found a possible signal candidate in L1 at 1204.70751953125 s with SNR 28.20580807368465
# We found a possible signal candidate in L1 at 196.08251953125 s with SNR 14.770698258139026
# We found a possible signal candidate in L1 at 1638.1396484375 s with SNR 13.702216956760536
# We found a possible signal candidate in L1 at 3319.25537109375 s with SNR 11.910464197181188
# We found a possible signal candidate in L1 at 2995.34228515625 s with SNR 8.869356663270473
# The following signal candidates in H1 were ruled out as glitches:
#
# The initial signal candidate at H1 reported at 987.69189453125 was a glitch
# The initial signal candidate at H1 reported at 1204.70751953125 was a glitch
# The initial signal candidate at H1 reported at 1638.15380859375 was a glitch
#
# The surviving signal candidates in H1 are:
#
# There is a signal candidate in H1 at 2995.3427734375 with SNR 10.165440937072812
# There is a signal candidate in H1 at 3319.255859375 with SNR 8.336510086945975
#
# The following signal candidates in L1 were ruled out as glitches:
#
# The initial signal candidate at L1 reported at 196.08251953125 was a glitch
# The initial signal candidate at L1 reported at 1204.70751953125 was a glitch
# The initial signal candidate at L1 reported at 1638.1396484375 was a glitch
# The initial signal candidate at L1 reported at 3319.25537109375 was a glitch
#
# The surviving signal candidates in L1 are:
#
# There is a signal candidate in L1 at 2995.34228515625 with SNR 8.021820771941414
#
# Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:
# The time lag 0.00048828125 s between the signals at H1 & L1 is too short compared to GW travel time and hence
# an artefact of other noise sources or some artificial source
#
#
# The signals at 3319.255859375 for H1 and at 2995.34228515625 for L1 are too far apart with a lag of 323.91357421875 s
#
# Individual masses of the BBHs --  32 solar masses
# Listing all the possible signal candidates(for BH mass= 32 solar mass) at Hanford in order of decreasing SNR
#
# We found a possible signal candidate in H1 at 1204.70703125 s with SNR 27.195530139935276
# We found a possible signal candidate in H1 at 1638.1533203125 s with SNR 18.498318553018304
# We found a possible signal candidate in H1 at 3319.25537109375 s with SNR 11.906776386535094
# We found a possible signal candidate in H1 at 2995.34228515625 s with SNR 11.270959797192129
# We found a possible signal candidate in H1 at 987.69189453125 s with SNR 8.80294041781573
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8be014784537> in <module>
#      72             x_mx1l.append(snr1_xmax)
#      73             y_mx1l.append(snr1_ymax)
# ---> 74             df_1 = df_1.drop(labels=range(max_i1 - BBH_dg, max_i1 + BBH_dg), axis=0)
#      75             maxv_snr1 = df_1["snr1_y"].max()
#      76             max_i1 = df_1["snr1_y"].idxmax()
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3811             else:
#    3812                 new_axis = axis.drop(labels, errors=errors)
# -> 3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#    3815         # Case for non-unique axis
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3807         kwargs.pop('axis', None)
#    3808         kwargs.pop('labels', None)
# -> 3809         return super(DataFrame, self).reindex(**kwargs)
#    3810
#    3811     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3739         if index is not None:
#    3740             frame = frame._reindex_index(index, method, copy, level,
# -> 3741                                          fill_value, limit, tolerance)
#    3742
#    3743         return frame
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3750         return self._reindex_with_indexers({0: [new_index, indexer]},
#    3751                                            copy=copy, fill_value=fill_value,
# -> 3752                                            allow_dups=False)
#    3753
#    3754     def _reindex_columns(self, new_columns, method, copy, level,
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1236             fill_value = fill_tuple[0]
#    1237             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1238                                        allow_fill=True, fill_value=fill_value)
#    1239
#    1240         if new_mgr_locs is None:
#
# ~/Tron/anaconda3/envs/igwn-py37/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1653     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#    1654                                  mask_info=mask_info)
# -> 1655     func(arr, indexer, out, fill_value)
#    1656
#    1657     if flip_order:
#
# KeyboardInterrupt:

# %%
masses = []
dth = 8  # BBH merger signal threshold
BBH_dg = 750
# Assuming that for any apparent signal detected there will be no other merger
# peak within .36secs on either side of the said tentative detection as\
# it is implausible

nbins = 26  # for the reduced chisq filtering of removing glitches
dof = nbins * 2 - 2  # for the reduced chisq filtering of removing glitches

for x in range(10, 12):
    print(Style.RESET_ALL)
    print(color.BOLD + "Individual masses of the BBHs -- ", x, "solar masses" + color.END)
    print(Style.RESET_ALL)

    hp1, _ = get_fd_waveform(
        approximant="IMRPhenomD",
        mass1=x,
        mass2=x,
        delta_f=data_H1.delta_f,
        f_lower=20.0)

    hp1.resize(len(psd_H1))

    snr1 = matched_filter(hp1, data_H1, psd=psd_H1, low_frequency_cutoff=20)

    snr1 = snr1.crop(5, 4)
    peak1 = abs(snr1).numpy().argmax()
    snrp1 = snr1[peak1]
    time1 = snr1.sample_times[peak1]

    hp2, _ = get_fd_waveform(
        approximant="IMRPhenomD",
        mass1=x,
        mass2=x,
        delta_f=data_L1.delta_f,
        f_lower=20.0)

    hp2.resize(len(psd_L1))

    snr2 = matched_filter(hp2, data_L1, psd=psd_L1, low_frequency_cutoff=20)

    snr2 = snr2.crop(5, 4)
    peak2 = abs(snr2).numpy().argmax()
    snrp2 = snr2[peak2]
    time2 = snr2.sample_times[peak2]

    plt.figure(figsize=[13.27, 5.17])
    plt.plot(snr1.sample_times, abs(snr1), "-b")
    plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
    plt.title("All Possible Signal Candidates in H1")
    plt.ylabel("Signal-to-noise")
    plt.xlabel("Time (s)")
    plt.show()

    df_1 = pd.DataFrame({"snr1_x": snr1.sample_times, "snr1_y": abs(snr1).numpy()})

    maxv_snr1 = df_1["snr1_y"].max()
    max_i1 = df_1["snr1_y"].idxmax()
    snr1_xmax = df_1["snr1_x"][max_i1]
    snr1_ymax = df_1["snr1_y"][max_i1]

    if maxv_snr1 >= dth:
        print(
            color.BLUEB + "Listing all the possible signal candidates(for BH mass=", x, "solar mass) at Hanford in order of decreasing SNR" + color.END)
        print(Style.RESET_ALL)
        x_mx1l = []
        y_mx1l = []
        while maxv_snr1 >= dth:
            print(color.CYAN + "We found a possible signal candidate in H1 at", str(snr1_xmax), "s with SNR", str(snr1_ymax) + color.END)

            x_mx1l.append(snr1_xmax)
            y_mx1l.append(snr1_ymax)
            df_1 = df_1.drop(labels=range(max_i1 - BBH_dg, max_i1 + BBH_dg), axis=0)
            maxv_snr1 = df_1["snr1_y"].max()
            max_i1 = df_1["snr1_y"].idxmax()
            snr1_xmax = df_1["snr1_x"][max_i1]
            snr1_ymax = df_1["snr1_y"][max_i1]

        print(Style.RESET_ALL)

        x_mx1ar = np.asarray(x_mx1l)
        y_mx1ar = np.asarray(y_mx1l)
        dfo_1 = (pd.DataFrame({"x1": x_mx1ar, "y1": y_mx1ar}).sort_values("x1").reset_index())

    else:
        print(color.BLUEB + "There were no signal candidates at Hanford" + color.END)
        print(Style.RESET_ALL)

    plt.figure(figsize=[13.27, 5.17])
    plt.plot(snr2.sample_times, abs(snr2), "-g")
    plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
    plt.title("All Possible Signal Candidates in L1")
    plt.ylabel("Signal-to-noise")
    plt.xlabel("Time (s)")
    plt.show()

    df_2 = pd.DataFrame({"snr2_x": snr2.sample_times, "snr2_y": abs(snr2).numpy()})

    maxv_snr2 = df_2["snr2_y"].max()
    max_i2 = df_2["snr2_y"].idxmax()
    snr2_xmax = df_2["snr2_x"][max_i2]
    snr2_ymax = df_2["snr2_y"][max_i2]

    if maxv_snr2 >= dth:
        print(color.GREENB + "Listing all the possible signal candidates(for BH mass=", x, "solar mass) at Livingston in order of decreasing SNR" + color.END)
        print(Style.RESET_ALL)
        x_mx2l = []
        y_mx2l = []
        while maxv_snr2 >= dth:
            print(color.LIGHTGREEN + "We found a possible signal candidate in L1 at", str(snr2_xmax), "s with SNR", str(snr2_ymax) + color.END)

            x_mx2l.append(snr2_xmax)
            y_mx2l.append(snr2_ymax)
            df_2 = df_2.drop(labels=range(max_i2 - BBH_dg, max_i2 + BBH_dg), axis=0)
            maxv_snr2 = df_2["snr2_y"].max()
            max_i2 = df_2["snr2_y"].idxmax()
            snr2_xmax = df_2["snr2_x"][max_i2]
            snr2_ymax = df_2["snr2_y"][max_i2]

        print(Style.RESET_ALL)

        x_mx2ar = np.asarray(x_mx2l)
        y_mx2ar = np.asarray(y_mx2l)
        dfo_2 = (pd.DataFrame({"x2": x_mx2ar, "y2": y_mx2ar}).sort_values("x2").reset_index())
    else:
        print(color.GREENB + "There were no signal candidates at Livingston" + color.END)
        print(Style.RESET_ALL)

    chisq_H1 = power_chisq(hp1, data_H1, nbins, psd_H1, low_frequency_cutoff=20.0)
    chisq_H1 = chisq_H1.crop(5, 4)
    chisq_H1 /= dof
    nsnr1 = newsnr(abs(snr1), chisq_H1)
    peak_H1 = nsnr1.argmax()
    snrp_H1 = nsnr1[peak_H1]
    time_H1 = snr1.sample_times[peak_H1]

    chisq_L1 = power_chisq(hp2, data_L1, nbins, psd_L1, low_frequency_cutoff=20.0)
    chisq_L1 = chisq_L1.crop(5, 4)
    chisq_L1 /= dof
    nsnr2 = newsnr(abs(snr2), chisq_L1)
    peak_L1 = nsnr2.argmax()
    snrp_L1 = nsnr2[peak_L1]
    time_L1 = snr2.sample_times[peak_L1]

    if snrp_H1 > dth:
        # print("For the Hanford data we found a confirmed signal at {}s with SNR {} after ruling out the other candidates as glitches".format(time_H1, abs(snrp_H1)))
        # print(Style.RESET_ALL)
        plt.figure(figsize=[13.27, 5.17])
        plt.plot(snr1.sample_times, nsnr1, "-b")
        plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
        plt.title("Remaining Signal Candidate in H1 after reweighing data")
        plt.xlabel("Time (s)")
        plt.ylabel("Re-weighted Signal-to-noise")
        plt.show()

        ndf_1 = pd.DataFrame({"x1": snr1.sample_times, "y1": nsnr1})
        max_value1 = ndf_1["y1"].max()
        max_index1 = ndf_1["y1"].idxmax()
        x_max1 = ndf_1["x1"][max_index1]
        y_max1 = ndf_1["y1"][max_index1]

        if max_value1 >= dth:
            # print(color.BOLD + "Listing all the remaining signal candidate(s) at Hanford" + color.END)
            # print(Style.RESET_ALL)
            x_max1l = []
            y_max1l = []
            while max_value1 >= dth:
                
                x_max1l.append(x_max1)
                y_max1l.append(y_max1)
                ndf_1 = ndf_1.drop(labels=range(max_index1 - BBH_dg, max_index1 + BBH_dg), axis=0)
                max_value1 = ndf_1["y1"].max()
                max_index1 = ndf_1["y1"].idxmax()
                x_max1 = ndf_1["x1"][max_index1]
                y_max1 = ndf_1["y1"][max_index1]

            x_max1ar = np.asarray(x_max1l)
            y_max1ar = np.asarray(y_max1l)
            dfn_1 = (pd.DataFrame({"X1": x_max1ar, "Y1": y_max1ar}).sort_values("X1").reset_index())
            cond1 = dfo_1["x1"].isin(dfn_1["X1"])  # condition for extracting glitches in H1
            dfo_gl1 = dfo_1.drop(dfo_1[cond1].index, inplace=False)  # glitch dataframe for H1
            dfo_gl1 = dfo_gl1.reset_index()

    else:
        print(color.BLUEB + "There were no signal candidates at Hanford for template using m1=m2=", x, "solar masses" + color.END)
        print(Style.RESET_ALL)
        dfo_gl1 = dfo_1
        dfn_1 = []

    if snrp_L1 > dth:
        # print("For the Livingston data we found a confirmed signal at {}s with SNR {} after ruling out the other candidates as glitches".format(time_L1, abs(snrp_L1)))
        # print(Style.RESET_ALL)
        plt.figure(figsize=[13.27, 5.17])
        plt.plot(snr2.sample_times, nsnr2, "-g")
        plt.axhline(y=8, color="black", linestyle="dashed", lw=2)
        plt.title("Remaining Signal Candidate in L1 after reweighing data")
        plt.xlabel("Time (s)")
        plt.ylabel("Re-weighted Signal-to-noise")
        plt.show()

        ndf_2 = pd.DataFrame({"x2": snr2.sample_times, "y2": nsnr2})
        max_value2 = ndf_2["y2"].max()
        max_index2 = ndf_2["y2"].idxmax()
        x_max2 = ndf_2["x2"][max_index2]
        y_max2 = ndf_2["y2"][max_index2]

        if max_value2 >= dth:
            # print(color.BOLD + "Listing all the remaining signal candidate(s) at Livingston" + color.END)
            # print(Style.RESET_ALL)
            x_max2l = []
            y_max2l = []
            while max_value2 >= dth:
                
                x_max2l.append(x_max2)
                y_max2l.append(y_max2)
                ndf_2 = ndf_2.drop(labels=range(max_index2 - BBH_dg, max_index2 + BBH_dg), axis=0)
                max_value2 = ndf_2["y2"].max()
                max_index2 = ndf_2["y2"].idxmax()
                x_max2 = ndf_2["x2"][max_index2]
                y_max2 = ndf_2["y2"][max_index2]

            x_max2ar = np.asarray(x_max2l)
            y_max2ar = np.asarray(y_max2l)
            dfn_2 = (pd.DataFrame({"X2": x_max2ar, "Y2": y_max2ar}).sort_values("X2").reset_index())
            cond2 = dfo_2["x2"].isin(dfn_2["X2"])  # condition for extracting glitches in L1
            dfo_gl2 = dfo_2.drop(dfo_2[cond2].index, inplace=False)  # glitch dataframe for L1
            dfo_gl2 = dfo_gl2.reset_index()

    else:
        print(color.GREENB + "There were no signal candidates at Livingston for template using m1=m2=", x, "solar masses" + color.END)
        print(Style.RESET_ALL)
        dfo_gl2 = dfo_2
        dfn_2 = []

    if (snrp_H1 > dth) or (snrp_L1 > dth) or ((snrp_H1 > dth) and (snrp_L1 > dth)):

        if len(dfn_1) > 0 and len(dfn_2) == 0:
            print(color.BLUEB + "There are no surviving signal candidates in L1 whereas for H1 we have", len(dfn_1), "candidates:" + color.END)
            print(Style.RESET_ALL)
            for i in range(0, dfn_1.index[-1] + 1):
                print(color.CYAN + "The signal candidate in H1 at", str(dfn_1["X1"][i]), "has a SNR of", str(dfn_1["Y1"][i]) + color.END)
            print(Style.RESET_ALL)
            print(color.GREENB + "The following signal candidates in L1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)
            for b in range(0, dfo_2.index[-1] + 1):
                print(color.LIGHTGREEN + "The initial signal candidate at L1 reported at", str(dfo_2["x2"][b]), "was a glitch" + color.END)

        elif len(dfn_2) > 0 and len(dfn_1) == 0:
            print(color.GREENB + "There are no surviving signal candidates in H1 whereas for L1 we have", len(dfn_2), "candidates:" + color.END)
            print(Style.RESET_ALL)
            for j in range(0, dfn_2.index[-1] + 1):
                print(color.LIGHTGREEN + "The signal candidate in L1 at", str(dfn_2["X2"][j]), "has a SNR of", str(dfn_2["Y2"][j]) + color.END)
            print(Style.RESET_ALL)
            print(color.BLUEB + "The following signal candidates in H1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)
            for a in range(0, dfo_1.index[-1] + 1):
                print(color.CYAN + "The initial signal candidate at H1 reported at", str(dfo_1["x1"][a]), "was a glitch" + color.END)

        elif len(dfn_2) > 0 and len(dfn_1) > 0:
            print(color.BLUEB + "The following signal candidates in H1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)

            if len(dfo_gl1) != 0:
                for g1 in range(0, dfo_gl1.index[-1] + 1):
                    print(color.CYAN + "The initial signal candidate at H1 reported at", str(dfo_gl1["x1"][g1]), "was a glitch" + color.END)
            if len(dfo_gl1) < len(dfo_1):
                print(Style.RESET_ALL)
                print(color.BLUEB + "The surviving signal candidates in H1 are:" + color.END)
                print(Style.RESET_ALL)
                for i in range(0, dfn_1.index[-1] + 1):
                    print(color.CYAN + "There is a signal candidate in H1 at", str(dfn_1["X1"][i]), "with SNR", str(dfn_1["Y1"][i]) + color.END)

            print(Style.RESET_ALL)
            print(color.GREENB + "The following signal candidates in L1 were ruled out as glitches:" + color.END)
            print(Style.RESET_ALL)

            if len(dfo_gl2) != 0:
                for g2 in range(0, dfo_gl2.index[-1] + 1):
                    print(color.LIGHTGREEN + "The initial signal candidate at L1 reported at", str(dfo_gl2["x2"][g2]), "was a glitch" + color.END)
            if len(dfo_gl2) < len(dfo_2):
                print(Style.RESET_ALL)
                print(color.GREENB + "The surviving signal candidates in L1 are:" + color.END)
                print(Style.RESET_ALL)
                for j in range(0, dfn_2.index[-1] + 1):
                    print(color.LIGHTGREEN + "There is a signal candidate in L1 at", str(dfn_2["X2"][j]), "with SNR", str(dfn_2["Y2"][j]) + color.END)

            print(Style.RESET_ALL)
            print(color.BOLD +"Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:" + color.END)
            #print(Style.RESET_ALL)
    
            for i in range(0,dfn_1.index[-1]+1): 
                for j in range(0,dfn_2.index[-1]+1):              

                    if dfn_1['X1'][i] == dfn_2['X2'][j]:
                        print(Style.RESET_ALL)  
                        print(color.BOLD + "As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at", dfn_1['X1'][i], 
                              "\nwith the H1 SNR", dfn_1['Y1'][i], "and the L1 SNR", dfn_2['Y2'][j], "." + color.END)
                        print(Style.RESET_ALL)  

                    elif dfn_2['X2'][j]-0.008961194 <= dfn_1['X1'][i] <= dfn_2['X2'][j]+0.008961194:

                        print(Style.RESET_ALL)
                        print(color.BOLD + "We found a BBH merger candidate \nin H1 at", dfn_1['X1'][i], "with SNR",dfn_1['Y1'][i],
                              "and \nin L1 at",dfn_2['X2'][j], "with SNR",dfn_2['Y2'][j], "." + color.END)
                        print(Style.RESET_ALL)

                        if abs(dfn_2['X2'][j]-dfn_1['X1'][i]) < 0.008961194:
                            #print(Style.RESET_ALL)
                            print(color.BOLD + "The time lag",abs(dfn_2['X2'][j]-dfn_1['X1'][i]) ,"s between the signals at H1 & L1 is too short compared to GW travel time and hence \nan artefact of other noise sources or some artificial source" + color.END)
                            print(Style.RESET_ALL)

                        else:
                            print(color.BLUEB + "yipee" + color.END)

                    elif dfn_2['X2'][j]-3 <= dfn_1['X1'][i] <= dfn_2['X2'][j]+3:

                        if abs(dfn_2['X2'][j]-dfn_1['X1'][i]) > 0.011328301:
                            print(Style.RESET_ALL)
                            print(color.BOLD + "While the time lag",abs(dfn_2['X2'][j]-dfn_1['X1'][i]) ,"s is short it is too large compared to GW travel time and hence an artefact of other noise sources" + color.END)
                            print(Style.RESET_ALL) 
                        elif ((abs(dfn_2['X2'][j]-dfn_1['X1'][i]) >=0.008961194) and (abs(dfn_2['X2'][j]-dfn_1['X1'][i]) < 0.011328301)): 
                            print(Style.RESET_ALL)
                            print(color.BOLD + "We found a signal candidate \nin H1 at", dfn_1['X1'][i], "with SNR",dfn_1['Y1'][i],
                                  "and \nin L1 at",dfn_2['X2'][j], "with SNR",dfn_2['Y2'][j], "." + color.END)
                            print(color.BOLD + "The above signal is an extremely likely candidate for an authentic BBH merger given the choice of template" + color.END)
                            print(color.BOLD + "The time lag",abs(dfn_2['X2'][j]-dfn_1['X1'][i]) ,"s between the signals at H1 & L1 is comparable to GW travel time" + color.END)
                            print(Style.RESET_ALL)  
                        else:
                            print(color.BLUEB + "yipee" + color.END)

                    elif abs(dfn_2['X2'][j]-dfn_1['X1'][i]) > 3:  

                        print(color.BOLD + "The signals at",dfn_1["X1"][i],"for H1 and at",dfn_2["X2"][j],"for L1 are too far apart with a lag of",abs(dfn_2['X2'][j]-dfn_1['X1'][i])," s" + color.END) 

    else:
        # print("Glitches and remaining signals")
        print(Style.RESET_ALL)
        # if len(dfn_1) == 0 and len(dfn_2) == 0:
        print(color.REDB + "There are no remaining signal candidates in both H1 and L1" + color.END)
        print(Style.RESET_ALL)
        for a in range(0, dfo_1.index[-1] + 1):
            print(color.CYAN + "The initial signal candidate at H1 reported at", str(dfo_1["x1"][a]), "was a glitch" + color.END)
        print(Style.RESET_ALL)
        for b in range(0, dfo_2.index[-1] + 1):
            print(color.LIGHTGREEN + "The initial signal candidate at L1 reported at", str(dfo_2["x2"][b]), "was a glitch" + color.END)

    masses.append(x)
# Out:
# Individual masses of the BBHs --  10 solar masses

# %%
plt.style.use('./plot.mplstyle')    
plt.figure(figsize=[13.27, 5.17])
plt.plot(snr2.sample_times, nsnr2, '-g')
plt.axhline(y = 8, color = 'black', linestyle = 'dashed')
plt.title('Remaining Signal Candidate in L1 after reweighing data')      
plt.xlabel('Time (s)')
plt.ylabel('Re-weighted Signal-to-noise')
plt.show()

# %%
import numpy as np
np.set_printoptions(precision=16, suppress=None)

x_max1ar = np.asarray(x_max1l)
x_max2ar = np.asarray(x_max2l)
y_max1ar = np.asarray(y_max1l)
y_max2ar = np.asarray(y_max2l)

#print(x_max1ar)
#print(x_max2ar)
#print(y_max1ar)
#print(y_max2ar)

dfn_1 = pd.DataFrame({'X1':x_max1ar, 'Y1':y_max1ar}).sort_values("X1").reset_index()
dfn_2 = pd.DataFrame({'X2':x_max2ar, 'Y2':y_max2ar}).sort_values("X2").reset_index()

print(dfn_1)
print(dfn_2)

if (len(dfn_1)==0 and len(dfn_2)==0):
  print('There are no remaining signal candidates in both H1 and L1')

elif (len(dfn_1)>0 and len(dfn_2)==0):
  print('There are no surviving signal candidates in L1 whereas for H1 we have',len(dfn_1),"candidates:")
  for i in range(0,dfn_1.index[-1]+1):
     print("There is a signal candidate in H1 at",dfn_1['X1'][i],"with SNR",dfn_1['Y1'][i])
    
elif (len(dfn_2)>0 and len(dfn_1)==0):
  print('There are no surviving signal candidates in H1 whereas for L1 we have',len(dfn_2),"candidates:")
  for j in range(0,dfn_2.index[-1]+1):
     print("There is a signal candidate in L1 at",dfn_2['X2'][j],"with SNR",dfn_2['Y2'][j])

    
elif ((len(dfn_2)>0 and len(dfn_1)>0) and (len(dfn_2)==len(dfn_1))):
    print(color.BLUEB +"The following signal candidates in H1 were ruled out as glitches:" + color.END)
    print(Style.RESET_ALL)
    
    
    
    
    
    print(Style.RESET_ALL)  
    print(color.BLUEB +"The surviving signal candidates in H1 are:" + color.END)
    print(Style.RESET_ALL)
    for i in range(0,dfn_1.index[-1]+1):
       print("There is a signal candidate in H1 at",dfn_1['X1'][i],"with SNR",dfn_1['Y1'][i])  
  
    print(color.GREENB +"The following signal candidates in L1 were ruled out as glitches:" + color.END)
    print(Style.RESET_ALL)
    
    
    
    
    
    print(color.GREENB +"The surviving signal candidates in L1 are:" + color.END)
    print(Style.RESET_ALL)  
    for j in range(0,dfn_2.index[-1]+1):
       print("There is a signal candidate in L1 at",dfn_2['X2'][j],"with SNR",dfn_2['Y2'][j])  
  
    print(Style.RESET_ALL)
    
    print(color.BOLD +"Checking if the surviving signal candidates fit the criteria for a BBH merger for our chosen template:" + color.END)
    #print(Style.RESET_ALL)
    
    for i in range(0,dfn_1.index[-1]+1): 
        for j in range(0,dfn_2.index[-1]+1):              
    
            if dfn_1['X1'][i] == dfn_2['X2'][j]:
                print(Style.RESET_ALL)  
                print("As the timestamps are exactly same we conclude an injected signal mimicking a BBH merger at", dfn_1['X1'][i], 
                      "\nwith the H1 SNR", dfn_1['Y1'][i], "and the L1 SNR", dfn_2['Y2'][j])
                print(Style.RESET_ALL)  
        
            elif dfn_2['X2'][j]-0.008961194 <= dfn_1['X1'][i] <= dfn_2['X2'][j]+0.008961194:
          
                print(Style.RESET_ALL)
                print("We found a BBH merger candidate \nin H1 at", dfn_1['X1'][i], "with SNR",dfn_1['Y1'][i],
                      "and \nin L1 at",dfn_2['X2'][j], "with SNR",dfn_2['Y2'][j])
                print(Style.RESET_ALL)
            
                if abs(dfn_2['X2'][j]-dfn_1['X1'][i]) < 0.008961194:
                    #print(Style.RESET_ALL)
                    print("The time lag",abs(dfn_2['X2'][j]-dfn_1['X1'][i]) ,"s between the signals at H1 & L1 is too short compared to GW travel time and hence \nan artefact of other noise sources or some artificial source")
                    print(Style.RESET_ALL)
            
                else:
                    print(color.BLUEB + "yipee" + color.END)
            
            elif dfn_2['X2'][j]-3 <= dfn_1['X1'][i] <= dfn_2['X2'][j]+3:
            
                if abs(dfn_2['X2'][j]-dfn_1['X1'][i]) > 0.011328301:
                    print(Style.RESET_ALL)
                    print("While the time lag",abs(dfn_2['X2'][j]-dfn_1['X1'][i]) ,"s is short it is too large compared to GW travel time and hence an artefact of other noise sources")
                    print(Style.RESET_ALL) 
                elif ((abs(dfn_2['X2'][j]-dfn_1['X1'][i]) >=0.008961194) and (abs(dfn_2['X2'][j]-dfn_1['X1'][i]) < 0.011328301)): 
                    print(Style.RESET_ALL)
                    print("We found a signal candidate \nin H1 at", dfn_1['X1'][i], "with SNR",dfn_1['Y1'][i],
                          "and \nin L1 at",dfn_2['X2'][j], "with SNR",dfn_2['Y2'][j])
                    print("The above signal is an extremely likely candidate for an authentic BBH merger given the choice of template")
                    print("The time lag",abs(dfn_2['X2'][j]-dfn_1['X1'][i]) ,"s between the signals at H1 & L1 is comparable to GW travel time")
                    print(Style.RESET_ALL)  
                else:
                    print(color.BLUEB + "yipee" + color.END)
            
            elif abs(dfn_2['X2'][j]-dfn_1['X1'][i]) > 3:  
          
                print("The signals at",dfn_1["X1"][i],"for H1 and at",dfn_2["X2"][j],"for L1 are too far apart with a lag of",abs(dfn_2['X2'][j]-dfn_1['X1'][i])," s")
# Out:
#    index           X1         Y1
# 0      0  2995.342773  10.165441
# 1      1  3319.255859   8.336510
#    index           X2        Y2
# 0      0  2995.342285  8.021821

# %%
from __future__ import division, print_function
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import bilby
from bilby.core.prior import Uniform
from bilby.gw.conversion import convert_to_lal_binary_black_hole_parameters, generate_all_bbh_parameters

from gwpy.timeseries import TimeSeries

sampling_rate=2048 #needs to be high enough for the signals found in steps above
duration=8 #needs to be long enough for the signals found in steps above
start_time=100 #needs to be set so that the segment defined by [start_time,start_time+duration] contains the signal

interferometers = bilby.gw.detector.InterferometerList([])
for ifo_name in ['H1','L1']:
    ifo=bilby.gw.detector.get_empty_interferometer(ifo_name)
    ifo.set_strain_data_from_frame_file('challenge3.gwf',sampling_rate, duration, start_time=start_time ,channel=ifo_name+':CHALLENGE3')
    interferometers.append(ifo)
# Out:
# 17:48 bilby INFO    : Reading data from frame file challenge3.gwf
# 17:48 bilby INFO    : Successfully loaded H1:CHALLENGE3.
# 17:48 bilby INFO    : Reading data from frame file challenge3.gwf
# 17:48 bilby INFO    : Successfully loaded L1:CHALLENGE3.
